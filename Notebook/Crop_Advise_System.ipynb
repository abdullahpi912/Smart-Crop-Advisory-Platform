# %% [markdown]
# # Module 2 – Day 19
# # Individual Machine Learning Project – Kickoff
#
# **Project:** Smart Crop Recommendation System
#
# This notebook completes the Day 19 tasks:
# 1. Project Initialization
# 2. Dataset Understanding
# 3. Initial Data Exploration
# 4. Project Planning
# 5. Repository Setup
# 6. Project Documentation

# %%
# Import required libraries
import pandas as pd

# Load the dataset
df = pd.read_csv("Crop_recommendation.csv")

# Display first five records
df.head()

# %% [markdown]
# ## 1. Project Initialization
#
# **Assigned Project:** Smart Crop Recommendation System
#
# **Problem Type:** Classification
#
# **Objective:**
# Build a machine learning model that recommends the most suitable crop based on soil nutrients and climatic conditions.

# %%
# Dataset Shape
print("Rows, Columns:", df.shape)

# Column Names
print("\nColumns:")
print(df.columns.tolist())

# %% [markdown]
# ## 2. Dataset Understanding
#
# - **Dataset Name:** Crop Recommendation Dataset
# - **Source:** Kaggle
# - **Target Variable:** label
#
# ### Feature Description
#
# | Feature | Description |
# |----------|-------------|
# | N | Nitrogen content |
# | P | Phosphorus content |
# | K | Potassium content |
# | temperature | Temperature (°C) |
# | humidity | Relative humidity (%) |
# | ph | Soil pH |
# | rainfall | Rainfall (mm) |
# | label | Recommended crop |

# %% [markdown]
# ## 3. Initial Data Exploration

# %%
# First five records
df.head()

# %%
# Data types
df.dtypes

# %%
# Missing values
df.isnull().sum()

# %%
# Summary statistics
df.describe()

# %%
# Numerical and categorical columns
numerical_columns = df.select_dtypes(include=["int64","float64"]).columns.tolist()
categorical_columns = df.select_dtypes(include=["object"]).columns.tolist()

print("Numerical Columns:", numerical_columns)
print("Categorical Columns:", categorical_columns)

# %% [markdown]
# ## 4. Project Planning
#
# ### Data Preprocessing
# - Check missing values
# - Verify data types
# - Train-test split
#
# ### Feature Engineering
# - Not required for the initial Decision Tree model.
#
# ### Planned Algorithms
# - Decision Tree
# - Random Forest (comparison)
#
# ### Reason
# Tree-based models perform well on this dataset and require minimal preprocessing.
#
# ### Evaluation Metrics
# - Accuracy
# - Weighted Precision
# - Weighted Recall
# - Weighted F1-score
# - Confusion Matrix
# - 5-Fold Cross Validation

# %% [markdown]
# ## 5. Repository Setup
#
# ```
# Smart-Crop-Recommendation-System/
# │
# ├── Dataset/
# ├── Notebook/
# ├── Model/
# ├── Documentation/
# └── README.md
# ```

# %% [markdown]
# ## 6. Project Documentation (README Summary)
#
# ### Project Title
# Smart Crop Recommendation System
#
# ### Problem Statement
# Recommend the best crop using soil nutrients and weather parameters.
#
# ### Technologies
# - Python
# - Pandas
# - NumPy
# - Scikit-learn
# - Matplotlib
# - Jupyter Notebook
#
# ### Planned Workflow
# 1. Load Dataset
# 2. Explore Data
# 3. Preprocess Data
# 4. Train Model
# 5. Evaluate Model
# 6. Save Model (.pkl)
# 7. Deploy in later modules
